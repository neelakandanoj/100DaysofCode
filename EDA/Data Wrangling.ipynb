# %% [markdown]
# # Importing Data

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r'E:\100 DaysOfCode\Projects\dataset\cardekho_dataset.csv',index_col=0)
df
# Out:
#               car_name     brand     model  vehicle_age  km_driven  \
# 0          Maruti Alto    Maruti      Alto            9     120000
# 1        Hyundai Grand   Hyundai     Grand            5      20000
# 2          Hyundai i20   Hyundai       i20           11      60000
# 3          Maruti Alto    Maruti      Alto            9      37000
# 4        Ford Ecosport      Ford  Ecosport            6      30000
# ...                ...       ...       ...          ...        ...
# 19537      Hyundai i10   Hyundai       i10            9      10723
# 19540    Maruti Ertiga    Maruti    Ertiga            2      18000
# 19541      Skoda Rapid     Skoda     Rapid            6      67000
# 19542  Mahindra XUV500  Mahindra    XUV500            5    3800000
# 19543       Honda City     Honda      City            2      13000
#
#       seller_type fuel_type transmission_type  mileage  engine  max_power  \
# 0      Individual    Petrol            Manual    19.70     796      46.30
# ...

# %%
df.columns
# Out:
# Index(['car_name', 'brand', 'model', 'vehicle_age', 'km_driven', 'seller_type',
#        'fuel_type', 'transmission_type', 'mileage', 'engine', 'max_power',
#        'seats', 'selling_price'],
#       dtype='object')

# %%
df.head(3)
# Out:
#         car_name    brand  model  vehicle_age  km_driven seller_type  \
# 0    Maruti Alto   Maruti   Alto            9     120000  Individual
# 1  Hyundai Grand  Hyundai  Grand            5      20000  Individual
# 2    Hyundai i20  Hyundai    i20           11      60000  Individual
#
#   fuel_type transmission_type  mileage  engine  max_power  seats  \
# 0    Petrol            Manual     19.7     796       46.3      5
# 1    Petrol            Manual     18.9    1197       82.0      5
# 2    Petrol            Manual     17.0    1197       80.0      5
#
#    selling_price
# 0         120000
# 1         550000
# 2         215000

# %%
df.shape
# Out:
# (15411, 13)

# %%
#dropping duplicate items
car_df=df.drop_duplicates()

# %%
car_df.shape
# Out:
# (15244, 13)

# %%
#Unique values of data
car_df['brand'].unique()
# Out:
# array(['Maruti', 'Hyundai', 'Ford', 'Renault', 'Mini', 'Mercedes-Benz',
#        'Toyota', 'Volkswagen', 'Honda', 'Mahindra', 'Datsun', 'Tata',
#        'Kia', 'BMW', 'Audi', 'Land Rover', 'Jaguar', 'MG', 'Isuzu',
#        'Porsche', 'Skoda', 'Volvo', 'Lexus', 'Jeep', 'Maserati',
#        'Bentley', 'Nissan', 'ISUZU', 'Ferrari', 'Mercedes-AMG',
#        'Rolls-Royce', 'Force'], dtype=object)

# %%
car_df['seller_type'].unique()
# Out:
# array(['Individual', 'Dealer', 'Trustmark Dealer'], dtype=object)

# %%
car_df['transmission_type'].unique()
# Out:
# array(['Manual', 'Automatic'], dtype=object)

# %%
#count the unique value using nunique
car_df['brand'].nunique()
# Out:
# 32

# %% [markdown]
# # subset of dataset

# %%
seller_1=car_df[car_df['seller_type']=='Individual']
seller_2=car_df[car_df['seller_type']=='Dealer']
seller_3=car_df[car_df['seller_type']=='Trustmark Dealer']

# %%
seller_1.shape
# Out:
# (5612, 13)

# %%
seller_2.shape
# Out:
# (9459, 13)

# %%
seller_3.shape
# Out:
# (173, 13)

# %% [markdown]
# # Concat

# %%
#concat both by default axis=0(vertical concatination)
all_seller=pd.concat([seller_1,seller_2,seller_3])
all_seller
# Out:
#              car_name    brand    model  vehicle_age  km_driven  \
# 0         Maruti Alto   Maruti     Alto            9     120000
# 1       Hyundai Grand  Hyundai    Grand            5      20000
# 2         Hyundai i20  Hyundai      i20           11      60000
# 3         Maruti Alto   Maruti     Alto            9      37000
# 5      Maruti Wagon R   Maruti  Wagon R            8      35000
# ...               ...      ...      ...          ...        ...
# 18166     Hyundai i20  Hyundai      i20            8      64321
# 18467  Maruti Celerio   Maruti  Celerio            4      54202
# 18696    Maruti Ignis   Maruti    Ignis            3      10503
# 18735     Maruti Ciaz   Maruti     Ciaz            3      21052
# 19448    Maruti Swift   Maruti    Swift            7      72597
#
#             seller_type fuel_type transmission_type  mileage  engine  \
# 0            Individual    Petrol            Manual    19.70     796
# ...

# %% [markdown]
# # Joins

# %%
high_km_drive=car_df[car_df['km_driven']>=20000]
high_km_drive
# Out:
#               car_name     brand     model  vehicle_age  km_driven  \
# 0          Maruti Alto    Maruti      Alto            9     120000
# 1        Hyundai Grand   Hyundai     Grand            5      20000
# 2          Hyundai i20   Hyundai       i20           11      60000
# 3          Maruti Alto    Maruti      Alto            9      37000
# 4        Ford Ecosport      Ford  Ecosport            6      30000
# ...                ...       ...       ...          ...        ...
# 19531     Maruti Swift    Maruti     Swift            3      25000
# 19533      Honda Amaze     Honda     Amaze            6      28000
# 19535    Maruti Ertiga    Maruti    Ertiga            5      56829
# 19541      Skoda Rapid     Skoda     Rapid            6      67000
# 19542  Mahindra XUV500  Mahindra    XUV500            5    3800000
#
#       seller_type fuel_type transmission_type  mileage  engine  max_power  \
# 0      Individual    Petrol            Manual    19.70     796      46.30
# ...

# %%
df.dtypes
# Out:
# car_name              object
# brand                 object
# model                 object
# vehicle_age            int64
# km_driven              int64
# seller_type           object
# fuel_type             object
# transmission_type     object
# mileage              float64
# engine                 int64
# max_power            float64
# seats                  int64
# selling_price          int64
# dtype: object

# %%
car_df['mileage'] = pd.to_numeric(car_df['mileage'], errors='coerce')

# Drop rows with missing values in 'mileage' column
car_df.dropna(subset=['mileage'], inplace=True)
# Out:
# C:\Users\IT PARK\AppData\Local\Temp\ipykernel_9608\1369682180.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car_df['mileage'] = pd.to_numeric(car_df['mileage'], errors='coerce')
# C:\Users\IT PARK\AppData\Local\Temp\ipykernel_9608\1369682180.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car_df.dropna(subset=['mileage'], inplace=True)

# %%
car_df
# Out:
#               car_name     brand     model  vehicle_age  km_driven  \
# 0          Maruti Alto    Maruti      Alto            9     120000
# 1        Hyundai Grand   Hyundai     Grand            5      20000
# 2          Hyundai i20   Hyundai       i20           11      60000
# 3          Maruti Alto    Maruti      Alto            9      37000
# 4        Ford Ecosport      Ford  Ecosport            6      30000
# ...                ...       ...       ...          ...        ...
# 19537      Hyundai i10   Hyundai       i10            9      10723
# 19540    Maruti Ertiga    Maruti    Ertiga            2      18000
# 19541      Skoda Rapid     Skoda     Rapid            6      67000
# 19542  Mahindra XUV500  Mahindra    XUV500            5    3800000
# 19543       Honda City     Honda      City            2      13000
#
#       seller_type fuel_type transmission_type  mileage  engine  max_power  \
# 0      Individual    Petrol            Manual    19.70     796      46.30
# ...

# %%
#Maing an average mileafe per brand
car_df.groupby(["brand"]).mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File e:\100 DaysOfCode\.venv\Lib\site-packages\pandas\core\groupby\groupby.py:1874, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1873 try:
# -> 1874     res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1875 except Exception as err:
#
# File e:\100 DaysOfCode\.venv\Lib\site-packages\pandas\core\groupby\ops.py:849, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     847     preserve_dtype = True
# --> 849 result = self._aggregate_series_pure_python(obj, func)
#     851 if len(obj) == 0 and len(result) == 0 and isinstance(obj.dtype, ExtensionDtype):
#
# File e:\100 DaysOfCode\.venv\Lib\site-packages\pandas\core\groupby\ops.py:877, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     876 for i, group in enumerate(splitter):
# --> 877     res = func(group)
# ...

# %%
import pandas as pd

# Assuming car_df is your DataFrame with 'brand' and 'mileage' columns

# Remove non-numeric characters from 'mileage' column and convert to numeric type
car_df['mileage'] = car_df['mileage'].str.replace('[^\d.]', '', regex=True)
car_df['mileage'] = pd.to_numeric(car_df['mileage'], errors='coerce')

# Drop rows with missing values in 'mileage' column
car_df.dropna(subset=['mileage'], inplace=True)

# Calculate the average mileage for each car brand
avg_mileage_df = car_df.groupby(by='brand')['mileage'].mean().reset_index()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[47], line 6
#       1 import pandas as pd
#       3 # Assuming car_df is your DataFrame with 'brand' and 'mileage' columns
#       4
#       5 # Remove non-numeric characters from 'mileage' column and convert to numeric type
# ----> 6 car_df['mileage'] = car_df['mileage'].str.replace('[^\d.]', '', regex=True)
#       7 car_df['mileage'] = pd.to_numeric(car_df['mileage'], errors='coerce')
#       9 # Drop rows with missing values in 'mileage' column
#
# File e:\100 DaysOfCode\.venv\Lib\site-packages\pandas\core\generic.py:6204, in NDFrame.__getattr__(self, name)
#    6197 if (
#    6198     name not in self._internal_names_set
#    6199     and name not in self._metadata
#    6200     and name not in self._accessors
#    6201     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202 ):
# ...
